# %%
p=[23,45,67]
x=[11,15,21]
import numpy as np
import pandas as pd
a=np.array(1)
b=np.array(x)
print(a)
print(b)
# Out:
# 1
# [11 15 21]

# %%
x=(1,2,3)
y=(4,5,6)
import matplotlib.pyplot as plt
plt.plot(x,y,'g')
